# %%
from imblearn.over_sampling import ADASYN, SMOTE, RandomOverSampler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import re
# Out:
# Using TensorFlow backend.

# %%
cf = pd.read_csv('clean_features.csv').set_index('PetID')
cf.AdoptionSpeed.value_counts()
# Out:
# 4    4197
# 2    4037
# 3    3259
# 1    3090
# 0     410
# Name: AdoptionSpeed, dtype: int64

# %%
X = cf.drop(columns = 'AdoptionSpeed')
y= cf['AdoptionSpeed']

smt = SMOTE(random_state=42, k_neighbors=5)
X_SMOTE, y_SMOTE = smt.fit_sample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_SMOTE, y_SMOTE , test_size = 0.2, random_state = 42)

# %%
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
logis = LogisticRegression(solver = 'lbfgs',max_iter = 1000)
logis.fit(X_train_s, y_train)
y_pred = logis.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.44699
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71       840
#            1       0.34      0.25      0.29       829
#            2       0.34      0.34      0.34       828
#            3       0.43      0.23      0.30       871
#            4       0.41      0.65      0.50       829
#
#     accuracy                           0.45      4197
#    macro avg       0.44      0.45      0.43      4197
# weighted avg       0.44      0.45      0.43      4197

# %%
y_pred_tr = logis.predict(X_train_s)
accuracy = metrics.accuracy_score(y_train, y_pred_tr)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_train, y_pred_tr))
# Out:
# Accuracy: 0.45133
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73      3357
#            1       0.35      0.26      0.30      3368
#            2       0.34      0.32      0.33      3369
#            3       0.40      0.22      0.28      3326
#            4       0.42      0.67      0.52      3368
#
#     accuracy                           0.45     16788
#    macro avg       0.44      0.45      0.43     16788
# weighted avg       0.44      0.45      0.43     16788

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
clf = GridSearchCV(LogisticRegression(penalty='l2',solver = 'lbfgs',max_iter = 1000), param_grid)
clf.fit(X_train_s, y_train)
y_pred = clf.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.44699
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71       840
#            1       0.34      0.25      0.29       829
#            2       0.34      0.34      0.34       828
#            3       0.43      0.23      0.30       871
#            4       0.41      0.65      0.50       829
#
#     accuracy                           0.45      4197
#    macro avg       0.44      0.45      0.43      4197
# weighted avg       0.44      0.45      0.43      4197

# %% [markdown]
# # Linear SVC

# %%
svc = SVC(kernel='linear')
svc.fit(X_train_s, y_train)
y_pred = svc.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.43650
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72       840
#            1       0.31      0.25      0.28       829
#            2       0.34      0.36      0.35       828
#            3       0.43      0.15      0.22       871
#            4       0.40      0.65      0.49       829
#
#     accuracy                           0.44      4197
#    macro avg       0.43      0.44      0.41      4197
# weighted avg       0.43      0.44      0.41      4197

# %% [markdown]
# #  Polynomial Kernel

# %%
svcpoly = SVC(kernel='poly', degree=8)
svcpoly.fit(X_train_s, y_train)
y_pred = svcpoly.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.28568
#               precision    recall  f1-score   support
#
#            0       0.25      0.97      0.39       840
#            1       0.41      0.10      0.17       829
#            2       0.36      0.10      0.16       828
#            3       0.49      0.13      0.20       871
#            4       0.48      0.12      0.19       829
#
#     accuracy                           0.29      4197
#    macro avg       0.40      0.29      0.22      4197
# weighted avg       0.40      0.29      0.22      4197

# %% [markdown]
# # Gaussian Kernel

# %%
svcrbf = SVC(kernel='rbf',probability=True)
svcrbf.fit(X_train_s, y_train)
y_pred = svcrbf.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-397e4fe7e99d> in <module>
#       1 svcrbf = SVC(kernel='rbf')
# ----> 2 svcrbf.fit(X_train_s, y_train)
#       3 y_pred = svcrbf.predict(X_test_s)
#       4 accuracy = metrics.accuracy_score(y_test, y_pred)
#       5 print('Accuracy: {:.5f}'.format(accuracy))
#
# //anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     197
#     198         seed = rnd.randint(np.iinfo('i').max)
# --> 199         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     200         # see comment on the other call to np.iinfo in this file
#     201
#
# //anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     256                 cache_size=self.cache_size, coef0=self.coef0,
#     257                 gamma=self._gamma, epsilon=self.epsilon,
# --> 258                 max_iter=self.max_iter, random_seed=random_seed)
#     259
#     260         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
svcrbf = SVC(kernel='rbf',probability=True)
svcrbf.fit(X_train_s, y_train)
y_pred_prob = svcrbf.predict_proba(X_test_s)

from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')
# Out:
# 0.7837217269071836

# %%
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(SVC(kernel='rbf'), param_grid)
grid.fit(X_train_s, y_train)
y_pred = grid.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))

roc_auc_score(y_true, y_scores)
# Out:
# Accuracy: 0.49297
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       840
#            1       0.40      0.38      0.39       829
#            2       0.34      0.36      0.35       828
#            3       0.43      0.31      0.36       871
#            4       0.47      0.52      0.49       829
#
#     accuracy                           0.49      4197
#    macro avg       0.48      0.49      0.49      4197
# weighted avg       0.48      0.49      0.48      4197

# %%
y_pred_tr = grid.predict(X_train_s)
accuracy = metrics.accuracy_score(y_train, y_pred_tr)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_train, y_pred_tr))
# Out:
# Accuracy: 0.80754
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      3357
#            1       0.79      0.74      0.77      3368
#            2       0.74      0.77      0.76      3369
#            3       0.85      0.69      0.76      3326
#            4       0.79      0.86      0.82      3368
#
#     accuracy                           0.81     16788
#    macro avg       0.81      0.81      0.81     16788
# weighted avg       0.81      0.81      0.81     16788

# %% [markdown]
# # Sigmoid Kernel

# %%
svcsig = SVC(kernel='sigmoid')
svcsig.fit(X_train_s, y_train)
y_pred = svcsig.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.34977
#               precision    recall  f1-score   support
#
#            0       0.60      0.66      0.63       840
#            1       0.25      0.27      0.26       829
#            2       0.23      0.19      0.21       828
#            3       0.26      0.19      0.22       871
#            4       0.35      0.44      0.39       829
#
#     accuracy                           0.35      4197
#    macro avg       0.34      0.35      0.34      4197
# weighted avg       0.34      0.35      0.34      4197

# %%
cf.corr(method ='pearson')
# Out:
#                           Type       Age    Gender  MaturitySize  FurLength  \
# Type                  1.000000 -0.147162  0.060843     -0.171811   0.003036
# Age                  -0.147162  1.000000 -0.123423      0.093673   0.153092
# Gender                0.060843 -0.123423  1.000000     -0.091819  -0.030404
# MaturitySize         -0.171811  0.093673 -0.091819      1.000000   0.095142
# FurLength             0.003036  0.153092 -0.030404      0.095142   1.000000
# Vaccinated            0.102907 -0.136061  0.078702     -0.087722  -0.006010
# Dewormed              0.025508 -0.053360  0.091431     -0.067352   0.016463
# Sterilized            0.006737 -0.189450  0.040645     -0.066321   0.032092
# Health               -0.006864  0.103215 -0.045177     -0.012957   0.028096
# Quantity              0.036423 -0.113076  0.494489     -0.042832  -0.038388
# Fee                  -0.042134  0.089168 -0.050491      0.041144   0.159693
# VideoAmt             -0.005967 -0.015969  0.016816      0.017032  -0.014740
# PhotoAmt              0.049368 -0.084778  0.098435      0.015593  -0.031557
# AdoptionSpeed        -0.091240  0.100510  0.057622      0.045653  -0.091337
# ColorNum              0.214481 -0.078636  0.244377     -0.056106  -0.000966
# NoName                0.022280 -0.086912  0.172005     -0.046481  -0.011671
# PureBreed             0.619819  0.115913 -0.046303     -0.160237   0.010613
# Tabby                 0.196281 -0.032766  0.001486     -0.031276  -0.031660
# Domestic_Short_Hair   0.653245 -0.124100  0.037355     -0.177485  -0.308249
# Domestic_Medium_Hair  0.361511 -0.075226  0.049176     -0.039691   0.263908
# Labrador_Retriever   -0.128318  0.043977 -0.009112      0.108027  -0.023701
# Terrier              -0.117828  0.028034 -0.012079      0.001994   0.066941
# Mixed_Breed          -0.819091 -0.119208 -0.000247      0.181021  -0.109643
# Other                 0.032582  0.333150 -0.072458     -0.017858   0.303067
# Color_Black           0.022574 -0.101595  0.125352      0.013855  -0.040086
# Color_Brown          -0.312223 -0.022183  0.070374      0.036012  -0.047699
# Color_Cream          -0.055426  0.039692  0.031792     -0.003899   0.054536
# Color_Golden          0.111046  0.041861 -0.000576      0.004018   0.046428
# Color_Gray            0.338007 -0.017376  0.075098     -0.080884   0.030517
# Color_White           0.221095 -0.021151  0.058503     -0.064051   0.001605
# 14                    0.000622  0.000280 -0.000691  0.000931  2.268856e-04
# 15                    1.000000 -0.000197  0.000486 -0.000655 -1.596622e-04
# 16                   -0.000197  1.000000  0.000219 -0.000295 -7.199205e-05
# 17                    0.000486  0.000219  1.000000  0.000729  1.775103e-04
# 18                   -0.000655 -0.000295  0.000729  1.000000 -2.391053e-04
# 19                   -0.000160 -0.000072  0.000178 -0.000239  1.000000e+00
#
# [67 rows x 67 columns]

# %%
imagef = pd.read_csv('img_features.csv').set_index('Unnamed: 0')

imagef.index.name = 'PetID'
imagef.head()
# Out:
#                   0         1         2         3         4         5  \
# PetID
# 86e1089a3  0.002000  0.167800  0.019715  0.015896  0.068162  0.002216
# 6296e909a  0.002858  0.107450  0.019916  0.023482  0.174765  0.002297
# 3422e4906  0.002734  0.072015  0.024455  0.018021  0.154207  0.001946
# 5842f1ff5  0.002106  0.274519  0.054815  0.013727  0.089969  0.001650
# 850a43f90  0.002185  0.174022  0.044818  0.016244  0.169775  0.002075
#
#                   6         7         8         9  ...       246       247  \
# PetID                                              ...
# 86e1089a3  0.005042  0.004828  0.050760  0.047626  ...  0.787699  0.176626
# 6296e909a  0.005031  0.006338  0.083378  0.049948  ...  0.628259  0.686865
# 3422e4906  0.004211  0.001576  0.100046  0.039717  ...  0.579116  0.557625
# 5842f1ff5  0.005506  0.004295  0.118727  0.034790  ...  1.295853  0.326143
# 850a43f90  0.004421  0.004157  0.099671  0.034441  ...  1.092663  0.669894
#
#                 248       249       250       251       252       253  \
# PetID
# 86e1089a3  0.575706  1.088628  0.439556  0.520460  1.547071  0.832573
# 6296e909a  0.564000  0.968190  1.070276  1.545742  0.894409  0.838595
# 3422e4906  1.131405  0.720513  1.496671  0.870955  1.289683  1.184462
# 5842f1ff5  0.291669  1.608086  1.119176  1.470889  0.591444  0.832755
# 850a43f90  0.395784  0.886075  1.219730  1.033966  1.065686  0.304054
#
#                 254       255
# PetID
# 86e1089a3  0.599093  0.763348
# 6296e909a  0.468238  0.916672
# 3422e4906  0.465114  0.892826
# 5842f1ff5  0.483021  1.134126
# 850a43f90  0.438069  0.676817
#
# [5 rows x 256 columns]

# %%
nmerge = imagef.merge(cf, on='PetID', how='outer')

# %%
nmerge.head()
# Out:
#                 0_x       1_x       2_x       3_x       4_x       5_x  \
# PetID
# 86e1089a3  0.002000  0.167800  0.019715  0.015896  0.068162  0.002216
# 6296e909a  0.002858  0.107450  0.019916  0.023482  0.174765  0.002297
# 3422e4906  0.002734  0.072015  0.024455  0.018021  0.154207  0.001946
# 5842f1ff5  0.002106  0.274519  0.054815  0.013727  0.089969  0.001650
# 850a43f90  0.002185  0.174022  0.044818  0.016244  0.169775  0.002075
#
#                 6_x       7_x       8_x       9_x  ...      10_y      11_y  \
# PetID                                              ...
# 86e1089a3  0.005042  0.004828  0.050760  0.047626  ...  0.009754 -0.002826
# 6296e909a  0.005031  0.006338  0.083378  0.049948  ... -0.010259  0.008178
# 3422e4906  0.004211  0.001576  0.100046  0.039717  ...  0.044125 -0.050633
# 5842f1ff5  0.005506  0.004295  0.118727  0.034790  ... -0.000498  0.044688
# 850a43f90  0.004421  0.004157  0.099671  0.034441  ... -0.009017  0.015145
#
#                12_y      13_y      14_y      15_y      16_y      17_y  \
# PetID
# 86e1089a3 -0.018925 -0.012456  0.000584 -0.014139 -0.007550  0.018987
# 6296e909a  0.010272  0.003087 -0.001423 -0.005038 -0.003081  0.009825
# 3422e4906  0.041106  0.008243  0.024158 -0.030801  0.012797 -0.050066
# 5842f1ff5 -0.034980  0.002213 -0.094938  0.060292  0.026551 -0.040345
# 850a43f90  0.099046  0.026728  0.011302  0.002314  0.000365  0.017789
#
#                18_y      19_y
# PetID
# 86e1089a3  0.009588  0.009349
# 6296e909a  0.003104  0.006718
# 3422e4906 -0.023363 -0.057766
# 5842f1ff5 -0.087958  0.000022
# 850a43f90  0.066420  0.038391
#
# [5 rows x 323 columns]

# %%
nmerge.AdoptionSpeed.value_counts()
# Out:
# 4    4197
# 2    4037
# 3    3259
# 1    3090
# 0     410
# Name: AdoptionSpeed, dtype: int64

# %%
X = nmerge.drop(columns = 'AdoptionSpeed')
y= nmerge['AdoptionSpeed']

smt = SMOTE(random_state=42, k_neighbors=5)
X_SMOTE, y_SMOTE = smt.fit_sample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_SMOTE, y_SMOTE , test_size = 0.2, random_state = 42)

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# %%
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(SVC(kernel='rbf'), param_grid)
grid.fit(X_train_s, y_train)
bestg = grid.best_estimator_
y_pred = bestg.predict(X_test_s)
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.62092
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       840
#            1       0.61      0.59      0.60       829
#            2       0.42      0.41      0.41       828
#            3       0.61      0.50      0.55       871
#            4       0.51      0.62      0.56       829
#
#     accuracy                           0.62      4197
#    macro avg       0.62      0.62      0.62      4197
# weighted avg       0.62      0.62      0.62      4197
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-22fdc93e8e6e> in <module>
#       9 print(classification_report(y_test, y_pred))
#      10
# ---> 11 roc_auc_score(y_true, y_scores)
#      12
#      13 y_pred_tr = bestg.predict(X_train_s)
#
# NameError: name 'roc_auc_score' is not defined

# %%
from sklearn.metrics import roc_auc_score
#roc_auc_score(y_test, y_pred_prob, multi_class = 'ovr')

y_pred_tr = bestg.predict(X_train_s)
accuracy = metrics.accuracy_score(y_train, y_pred_tr)
print('Accuracy: {:.5f}'.format(accuracy))
print(classification_report(y_train, y_pred_tr))
# Out:
# Accuracy: 0.99643
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3357
#            1       1.00      0.99      1.00      3368
#            2       1.00      0.99      1.00      3369
#            3       1.00      1.00      1.00      3326
#            4       0.99      1.00      0.99      3368
#
#     accuracy                           1.00     16788
#    macro avg       1.00      1.00      1.00     16788
# weighted avg       1.00      1.00      1.00     16788
